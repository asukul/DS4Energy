# %% [markdown]
# <a href="https://colab.research.google.com/github/asukul/DS201/blob/master/Working_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Working with pandas tutorial.
# //Adisak Sukul

# %%
import pandas as pd

# %% [markdown]
# how to read data into pandas
# read_csv()
# read_table() for tab delimited data

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
orders.head(20)
# Out:
#     order_id  ...  item_price
# 0          1  ...      $2.39
# 1          1  ...      $3.39
# 2          1  ...      $3.39
# 3          1  ...      $2.39
# 4          2  ...     $16.98
# 5          3  ...     $10.98
# 6          3  ...      $1.69
# 7          4  ...     $11.75
# 8          4  ...      $9.25
# 9          5  ...      $9.25
# 10         5  ...      $4.45
# 11         6  ...      $8.75
# 12         6  ...      $8.75
# 13         7  ...     $11.25
# 14         7  ...      $4.45
# 15         8  ...      $2.39
# 16         8  ...      $8.49
# 17         9  ...      $8.49
# 18         9  ...      $2.18
# 19        10  ...      $8.75
#
# [20 rows x 5 columns]

# %%
orders.tail(10)
# Out:
#       order_id  ...  item_price
# 4612      1831  ...      $9.25
# 4613      1831  ...      $2.15
# 4614      1831  ...      $1.50
# 4615      1832  ...      $8.75
# 4616      1832  ...      $4.45
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [10 rows x 5 columns]

# %%
movies = pd.read_table('http://bit.ly/movieusers')

# %%
movies
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %% [markdown]
# we need a seperater
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html

# %%
pd.read_table('http://bit.ly/movieusers',sep='|')
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
pd.read_table('http://bit.ly/movieusers', header=None, sep='|')
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
movies =pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols)

# %%
movies.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#skiprows=None to skip specific row
#skipfooter=0 to skip footer

# %%
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
movies =pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols, skiprows=3)

# %%
movies.head()
# Out:
#    user_id  age gender     occupation zip_code
# 0        4   24      M     technician    43537
# 1        5   33      F          other    15213
# 2        6   42      M      executive    98101
# 3        7   57      M  administrator    91344
# 4        8   36      M  administrator    05201

# %% [markdown]
# How to select a pandas Series from a DataFrame?

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo['State'])
# Out:
# pandas.core.series.Series

# %%
type(ufo['City']) # <== case sensitive
# Out:
# pandas.core.series.Series

# %%
ufo["Colors Reported"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %%
ufo.City # Dot notation. Any columns added into Dataframe become an "Attribute" of the DataFrame.
#Dot notation is a little bit shorter to type. However, it won't work in all cases. So stick with [] notaion.
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
#ufo.Colors Reported

# %%
#you can also Concatinate columns by using +

# %%
'DS' + '201' + 'XW'
# Out:
# 'DS201XW'

# %%
ufo["City"] + ", "+ ufo["State"]
# Out:
# 0                      Ithaca, NY
# 1                 Willingboro, NJ
# 2                     Holyoke, CO
# 3                     Abilene, KS
# 4        New York Worlds Fair, NY
#                    ...
# 18236              Grant Park, IL
# 18237             Spirit Lake, IA
# 18238             Eagle River, WI
# 18239             Eagle River, WI
# 18240                    Ybor, FL
# Length: 18241, dtype: object

# %%
ufo.City + ", " +ufo.State
# Out:
# 0                      Ithaca, NY
# 1                 Willingboro, NJ
# 2                     Holyoke, CO
# 3                     Abilene, KS
# 4        New York Worlds Fair, NY
#                    ...
# 18236              Grant Park, IL
# 18237             Spirit Lake, IA
# 18238             Eagle River, WI
# 18239             Eagle River, WI
# 18240                    Ybor, FL
# Length: 18241, dtype: object

# %%
#now create a new column
#ufo['Location'] = ufo.City + ", " +ufo.State

# %%
ufo['Location']=ufo['City']+", "+ufo['State']

# %%
ufo.head(10)
# Out:
#                    City  ...                  Location
# 0                Ithaca  ...                Ithaca, NY
# 1           Willingboro  ...           Willingboro, NJ
# 2               Holyoke  ...               Holyoke, CO
# 3               Abilene  ...               Abilene, KS
# 4  New York Worlds Fair  ...  New York Worlds Fair, NY
# 5           Valley City  ...           Valley City, ND
# 6           Crater Lake  ...           Crater Lake, CA
# 7                  Alma  ...                  Alma, MI
# 8               Eklutna  ...               Eklutna, AK
# 9               Hubbard  ...               Hubbard, OR
#
# [10 rows x 6 columns]

# %% [markdown]
# How to select multiple rows and columns from a pandas DataFrame?

# %%
ufo.head(3)
#pick first 3 rows
# Out:
#           City Colors Reported  ...             Time         Location
# 0       Ithaca             NaN  ...   6/1/1930 22:00       Ithaca, NY
# 1  Willingboro             NaN  ...  6/30/1930 20:00  Willingboro, NJ
# 2      Holyoke             NaN  ...  2/15/1931 14:00      Holyoke, CO
#
# [3 rows x 6 columns]

# %%
# .loc is for selecting things by label
# pd.loc[row,col]
ufo.loc[2]
# Out:
# City                       Holyoke
# Colors Reported                NaN
# Shape Reported                OVAL
# State                           CO
# Time               2/15/1931 14:00
# Location               Holyoke, CO
# Name: 2, dtype: object

# %%
#pass in the list for multiple rows
ufo.loc[[0,1,3,5,10],['City','Colors Reported']]
# Out:
#            City Colors Reported
# 0        Ithaca             NaN
# 1   Willingboro             NaN
# 3       Abilene             NaN
# 5   Valley City             NaN
# 10      Fontana             NaN

# %%
ufo.iloc[[0,1,3,5,10],[0,1,3]]
# Out:
#            City Colors Reported State
# 0        Ithaca             NaN    NY
# 1   Willingboro             NaN    NJ
# 3       Abilene             NaN    KS
# 5   Valley City             NaN    ND
# 10      Fontana             NaN    CA

# %%
#pass in the range for multiple continuous rows
ufo.loc[0:4,:]
# Out:
#                    City  ...                  Location
# 0                Ithaca  ...                Ithaca, NY
# 1           Willingboro  ...           Willingboro, NJ
# 2               Holyoke  ...               Holyoke, CO
# 3               Abilene  ...               Abilene, KS
# 4  New York Worlds Fair  ...  New York Worlds Fair, NY
#
# [5 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ufo2 = ufo.groupby(['State']).size()

# %%
ufo2.plot.bar();
#plt.show()

# %%
ufo2.plot.bar(figsize=(15,10));
plt.show()
